# %% [markdown]
# # Purpose
#
# Now that we have the data for each of our customers (see notebook 00_Generating_100Customers_NV), and data for each product our grocery shop sells (see 01_Scrape_Tesco_Groceries_NV), we can now prepare the data so that it is easier to simulate.
#
# This means we'll be assigning an ID to each customer and to each item, so that it becomes easier to store, and we'll decide on how to store information about each transaction.

# %%
import numpy as np
import pandas as pd
from pprint import pprint

# %%
customers = pd.read_json(
    '../data/processed/customers.json'
)
display(customers.sample(5))
print(customers.shape)

items = pd.read_json(
    '../data/raw/sample_products.json'
)
display(items.sample(5))
print(items.shape)
# Out:
#     age     habit  budget
# 8    26  sporadic   115.0
# 65   26  sporadic   115.0
# 32   70  sporadic   115.0
# 95   63  sporadic   115.0
# 11   30  sporadic   115.0
# (100, 3)
#                                            product  price               type
# 105                                   Diet Coke 2L   1.77             drinks
# 227       Swan Menthol Extra Slim Filters 120 Pack   1.03      home-and-ents
# 126         Milton Antibacterial Surface Wipes X30   2.00               baby
# 150  Colgate Deep Clean Whitening Toothpaste 125Ml   3.80  health-and-beauty
# 23                             Whole Cucumber Each   0.43         fresh-food
# (240, 3)

# %% [markdown]
# We need to generate a unique ID for each customer. We do this so that we can store a customer ID in a database, and not the 3 columns we currently have. The same holds for the items.
#
# One quick way to do this is to generate a unique ID using python's built-in `uuid` module.

# %%
import uuid

# %% [markdown]
# `uuid` has a handy function, `.uuid4()`, which generates a random ID.

# %%
uuid.uuid4()
# Out:
# UUID('489df39d-e2ac-4718-91cd-ddaf36d4c96c')

# %% [markdown]
# We can then use the `.fields` attribute to get a numeric ID.

# %%
uuid.uuid4().fields
# Out:
# (803145970, 45464, 17617, 143, 242, 198400897234744)

# %% [markdown]
# Since this is a fairly lightweight operation, we will use the first field, as it always yields a 32-bit integer. In other applications, we can use the other fields. We need to make sure to keep a record of which customers have which ID!

# %%
customers['uuid'] = [uuid.uuid4().fields[0] for _ in range(len(customers))]
print(len(customers['uuid'].unique()))
# Out:
# 100

# %% [markdown]
# And with this we have 100 unique IDs, one for each customer. Let's keep a record of the new data, now in CV format.

# %%
customers.to_csv('../data/processed/customers_database.csv', index=False)

# %% [markdown]
# Now we do the same for the items. For practice, let's use one of the 16-bit integer fields.

# %%
items['uuid'] = [uuid.uuid4().fields[1] for _ in range(len(items))]
print(len(items['uuid'].unique()))
# Out:
# 240

# %% [markdown]
# And we save.

# %%
items.to_csv('../data/processed/items_database.csv', index=False)

# %% [markdown]
# Onto a simple simulation.
#
# ### Simple simulations
#
# Now that we have a list of customers, with budgets, and a list of products they could buy, with prices, we can simulate a shopping interaction. For simplicity, we will assume that customer who shop daily buy something from every category every day.
#
# Let's start simple. For a given customer, we sample an item, add the cost to the bill, then check if the bill exceeds the budget. If it does, we pop the last item and checkout. In this scenario, a customer is just as likely to buy 2 packs of bananas, or 2 household items.

# %%
def generate_bill(customer: pd.Series, items: pd.DataFrame) -> (list, list):
    """
    Purchases for a single customer.
    
    We add items to a customer's basket, at random, and check if the
    sub-total exceeds the customer's budget.
    """
    items_purchased = []
    sub_total = []
    cust_budget = customer['budget']
    while sum(sub_total) < cust_budget:
        item = items.sample()
        sub_total.append(item['price'].values[0])
        items_purchased.append(item['uuid'].values[0])
    if sum(sub_total) > customer['budget']:
        sub_total.pop()
        items_purchased.pop()
    return items_purchased, sub_total

# %%
# Let's test
generate_bill(
    customer=customers.query('habit == "daily"').iloc[0],
    items=items
)
# Out:
# ([31458, 60756], [1.5, 0.8])

# %% [markdown]
# Since we have a way to generate bills, so now we need to generate bills for one day for every customer, and bills for one week.

# %%
# We don't know when weekly customers will come in, so we will assign a
# random number, from 0 to 6, which will dictate when the "weekly" customers
# come in.
weekly_customers = customers.query('habit == "weekly"')
weekly_customers['day_in'] = np.random.randint(
    0, 7, 
    size=len(weekly_customers)
)
display(weekly_customers)
# Out:
# /var/folders/jl/t12wn_1x05g2w2xy8_n9drh00000gn/T/ipykernel_953/3008176895.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weekly_customers['day_in'] = np.random.randint(
#     age   habit  budget        uuid  day_in
# 0    24  weekly    26.5  3031153441       2
# 2    82  weekly    26.5   464317747       5
# 3    75  weekly    26.5  1412573174       0
# 5    52  weekly    26.5  3785220396       6
# 12   85  weekly    26.5  4178248121       6
# 14   46  weekly    26.5  3982346988       5
# 17   92  weekly    26.5  3745847835       4
# 18   85  weekly    26.5   789231310       4
# 19   54  weekly    26.5  2493851942       1
# 20   84  weekly    26.5   961301073       3
# 24   60  weekly    26.5  3505877984       6
# 25   61  weekly    26.5  2630012468       2
# 27   86  weekly    26.5    17985943       5
# 28   37  weekly    26.5  3006901239       1
# 31   82  weekly    26.5  4079302491       1
# 34   24  weekly    26.5  4008714709       0
# 37   38  weekly    26.5  3594794604       1
# 40   59  weekly    26.5  1232284025       6
# 42   70  weekly    26.5  1161697091       5
# 44   81  weekly    26.5  3325278451       2
# 45   93  weekly    26.5  4080807039       5
# 46   52  weekly    26.5  2546376173       3
# 47   33  weekly    26.5  4054437080       5
# 49   66  weekly    26.5   824870520       6
# 51   43  weekly    26.5   761977121       2
# 52   74  weekly    26.5   915486375       3
# 53   53  weekly    26.5  2041761052       2
# 54   29  weekly    26.5  2983884575       0
# 60   81  weekly    26.5  1615855092       1
# 61   92  weekly    26.5  2588521857       1
# 63   27  weekly    26.5   683775536       4
# 64   70  weekly    26.5  3396477435       6
# 69   42  weekly    26.5  3558862810       5
# 70   75  weekly    26.5  2262950664       4
# 71   83  weekly    26.5   250142846       1
# 74   57  weekly    26.5   109759433       4
# 76   58  weekly    26.5  2326982145       2
# 78   82  weekly    26.5   952267414       4
# 80   37  weekly    26.5  1504822002       6
# 82   72  weekly    26.5  3397042353       0
# 83   97  weekly    26.5   603295827       4
# 85   97  weekly    26.5  3444299591       2
# 87   43  weekly    26.5  3543316534       0
# 89   19  weekly    26.5  1605758201       0
# 92   39  weekly    26.5  1720291968       5
# 93   60  weekly    26.5  3957693635       5
# 94   48  weekly    26.5  3391121701       5
# 96   23  weekly    26.5   106098987       4
# 98   52  weekly    26.5  1660986885       6
# 99   88  weekly    26.5   532895532       3

# %% [markdown]
# So now we can simulate a week's worth of billings. Let's ignore the hour component in the simulation for now.

# %%
for day in range(7):  # Sunday is 0
    todays_customers = customers.query('habit == "daily"').append(
        weekly_customers.query(f'day_in == {day}')
    )
    for idx,customer in todays_customers.iterrows():
        display(generate_bill(customer, items))
    break
# Out:
# ([41231], [3.75])
# ([14117, 13222, 33464, 59734], [0.7000000000000001, 1.3, 0.5, 1.0])
# ([25512], [1.0])
# ([25764, 41428, 552, 54369, 60756, 4367, 3628, 11921],
#  [1.85, 2.2, 7.0, 11.0, 0.8, 0.75, 0.85, 0.6000000000000001])
# ([13413, 26335, 19902, 6133, 27893, 35126, 18736],
#  [4.0, 0.7000000000000001, 1.0, 1.77, 0.99, 1.5, 9.5])
# ([48466, 13824, 20944, 43094, 46027, 13413, 12388, 23858, 57458, 39324, 39962],
#  [7.6, 1.48, 1.5, 1.5, 1.0, 4.0, 2.0, 1.0, 0.55, 2.85, 1.65])
# ([7737, 46027, 28275, 26820, 60151, 28451, 28474, 24832, 43692, 2846, 30113],
#  [1.5,
#   1.0,
#   1.46,
#   1.35,
#   9.75,
#   0.55,
#   1.5,
#   0.9500000000000001,
#   1.5,
#   2.95,
#   1.9500000000000002])
# ([53453,
#   64049,
#   23876,
#   52269,
#   52529,
#   49701,
#   50775,
#   14588,
#   18633,
#   13824,
#   48361,
#   2846,
#   35126,
#   1584,
#   27893,
#   23876,
#   35566,
#   5651],
#  [1.55,
#   1.0,
#   1.13,
#   1.0,
#   0.9,
#   2.0,
#   0.6900000000000001,
#   1.15,
#   0.7000000000000001,
#   1.48,
#   0.85,
#   2.95,
#   1.5,
#   2.5,
#   0.99,
#   1.13,
#   1.0,
#   1.48])
# ([5651, 52171, 49258, 10921, 25652, 39073, 52381, 30026, 16744, 60791],
#  [1.48, 0.6000000000000001, 0.99, 1.5, 1.46, 13.0, 1.25, 1.0, 1.0, 3.29])

# %% [markdown]
# Ok, the skeleton is there. All we now need is to store the day and generate a unique transaction ID, for which we can rely again on `uuid`.

# %%
billings = []
for day in range(7):  # Sunday is 0
    todays_customers = customers.query('habit == "daily"').append(
        weekly_customers.query(f'day_in == {day}')
    )
    for idx,customer in todays_customers.set_index('uuid').iterrows():
        bill = generate_bill(customer, items)
        bill_id = uuid.uuid4().fields[0]
        for it,pr in zip(bill[0], bill[1]):
            billings.append(
                {
                    'id': bill_id,
                    'day': day,
                    'customer_id': idx,
                    'items': it,
                    'total': pr
                }
            )
pprint(billings)
# Out:
# [{'customer_id': 958420868,
#   'day': 0,
#   'id': 217520049,
#   'items': 48607,
#   'total': 1.8},
#  {'customer_id': 958420868,
#   'day': 0,
#   'id': 217520049,
#   'items': 3058,
#   'total': 0.9},
#  {'customer_id': 958420868,
#   'day': 0,
#   'id': 217520049,
#   'items': 18633,
#   'total': 0.7000000000000001},
#  {'customer_id': 4036240255,
#   'day': 0,
#   'id': 2564927050,
#   'items': 62726,
#   'total': 1.75},
#  {'customer_id': 1412573174,
#   'day': 0,
#   'id': 2842132865,
#   'items': 16846,
#   'total': 1.0},
#  {'customer_id': 1412573174,
#   'day': 0,
#   'id': 2842132865,
#   'items': 43692,
#   'total': 1.5},
#  {'customer_id': 1412573174,
#   'day': 0,
#   'id': 2842132865,
#   'items': 62913,
#   'total': 1.8},
#  {'customer_id': 1412573174,
#   'day': 0,
#   'id': 2842132865,
#   'items': 63618,
#   'total': 4.0},
#  {'customer_id': 1412573174,
#   'day': 0,
#   'id': 2842132865,
#   'items': 18736,
#   'total': 9.5},
#  {'customer_id': 1412573174,
#   'day': 0,
#   'id': 2842132865,
#   'items': 56792,
#   'total': 1.65},
#  {'customer_id': 1412573174,
#   'day': 0,
#   'id': 2842132865,
#   'items': 57525,
#   'total': 1.0},
#  {'customer_id': 1412573174,
#   'day': 0,
#   'id': 2842132865,
#   'items': 60756,
#   'total': 0.8},
#  {'customer_id': 1412573174,
#   'day': 0,
#   'id': 2842132865,
#   'items': 43875,
#   'total': 1.0},
#  {'customer_id': 1412573174,
#   'day': 0,
#   'id': 2842132865,
#   'items': 64049,
#   'total': 1.0},
#  {'customer_id': 1412573174,
#   'day': 0,
#   'id': 2842132865,
#   'items': 36126,
#   'total': 1.45},
#  {'customer_id': 4008714709,
#   'day': 0,
#   'id': 731372757,
#   'items': 47290,
#   'total': 0.30000000000000004},
#  {'customer_id': 4008714709,
#   'day': 0,
#   'id': 731372757,
#   'items': 46067,
#   'total': 3.1},
#  {'customer_id': 4008714709,
#   'day': 0,
#   'id': 731372757,
#   'items': 13222,
#   'total': 1.3},
#  {'customer_id': 4008714709,
#   'day': 0,
#   'id': 731372757,
#   'items': 57769,
#   'total': 1.0},
#  {'customer_id': 4008714709,
#   'day': 0,
#   'id': 731372757,
#   'items': 53728,
#   'total': 1.1},
#  {'customer_id': 4008714709,
#   'day': 0,
#   'id': 731372757,
#   'items': 49315,
#   'total': 7.5},
#  {'customer_id': 4008714709,
#   'day': 0,
#   'id': 731372757,
#   'items': 35773,
#   'total': 0.45},
#  {'customer_id': 4008714709,
#   'day': 0,
#   'id': 731372757,
#   'items': 62913,
#   'total': 1.8},
#  {'customer_id': 4008714709,
#   'day': 0,
#   'id': 731372757,
#   'items': 65180,
#   'total': 0.35000000000000003},
#  {'customer_id': 4008714709,
#   'day': 0,
#   'id': 731372757,
#   'items': 34797,
#   'total': 2.5},
#  {'customer_id': 4008714709,
#   'day': 0,
#   'id': 731372757,
#   'items': 2846,
#   'total': 2.95},
#  {'customer_id': 4008714709,
#   'day': 0,
#   'id': 731372757,
#   'items': 17440,
#   'total': 1.25},
#  {'customer_id': 4008714709,
#   'day': 0,
#   'id': 731372757,
#   'items': 11836,
#   'total': 2.0},
#  {'customer_id': 2983884575,
#   'day': 0,
#   'id': 2970587888,
#   'items': 43632,
#   'total': 2.5},
#  {'customer_id': 2983884575,
#   'day': 0,
#   'id': 2970587888,
#   'items': 26335,
#   'total': 0.7000000000000001},
#  {'customer_id': 2983884575,
#   'day': 0,
#   'id': 2970587888,
#   'items': 16846,
#   'total': 1.0},
#  {'customer_id': 2983884575,
#   'day': 0,
#   'id': 2970587888,
#   'items': 60791,
#   'total': 3.29},
#  {'customer_id': 2983884575,
#   'day': 0,
#   'id': 2970587888,
#   'items': 18016,
#   'total': 1.3},
#  {'customer_id': 2983884575,
#   'day': 0,
#   'id': 2970587888,
#   'items': 42234,
#   'total': 0.6000000000000001},
#  {'customer_id': 2983884575,
#   'day': 0,
#   'id': 2970587888,
#   'items': 43875,
#   'total': 1.0},
#  {'customer_id': 2983884575,
#   'day': 0,
#   'id': 2970587888,
#   'items': 16846,
#   'total': 1.0},
#  {'customer_id': 2983884575,
#   'day': 0,
#   'id': 2970587888,
#   'items': 24832,
#   'total': 0.9500000000000001},
#  {'customer_id': 2983884575,
#   'day': 0,
#   'id': 2970587888,
#   'items': 59734,
#   'total': 1.0},
#  {'customer_id': 2983884575,
#   'day': 0,
#   'id': 2970587888,
#   'items': 53432,
#   'total': 1.45},
#  {'customer_id': 2983884575,
#   'day': 0,
#   'id': 2970587888,
#   'items': 49701,
#   'total': 2.0},
#  {'customer_id': 2983884575,
#   'day': 0,
#   'id': 2970587888,
#   'items': 17670,
#   'total': 1.0},
#  {'customer_id': 2983884575,
#   'day': 0,
#   'id': 2970587888,
#   'items': 45061,
#   'total': 0.85},
#  {'customer_id': 2983884575,
#   'day': 0,
#   'id': 2970587888,
#   'items': 49315,
#   'total': 7.5},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 60756,
#   'total': 0.8},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 29445,
#   'total': 1.0},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 41181,
#   'total': 2.0},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 24056,
#   'total': 1.2},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 31297,
#   'total': 1.1},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 46547,
#   'total': 1.6},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 3431,
#   'total': 0.9500000000000001},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 13009,
#   'total': 1.46},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 63594,
#   'total': 1.46},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 23479,
#   'total': 0.35000000000000003},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 5049,
#   'total': 0.5},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 14679,
#   'total': 0.6000000000000001},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 33067,
#   'total': 0.9},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 53480,
#   'total': 0.75},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 11726,
#   'total': 0.85},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 57741,
#   'total': 0.43},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 39686,
#   'total': 0.68},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 43632,
#   'total': 2.5},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 18940,
#   'total': 3.5},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 23858,
#   'total': 1.0},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 43875,
#   'total': 1.0},
#  {'customer_id': 3397042353,
#   'day': 0,
#   'id': 89006164,
#   'items': 7244,
#   'total': 0.79},
#  {'customer_id': 3543316534,
#   'day': 0,
#   'id': 4224613223,
#   'items': 52196,
#   'total': 2.9},
#  {'customer_id': 3543316534,
#   'day': 0,
#   'id': 4224613223,
#   'items': 26352,
#   'total': 2.0},
#  {'customer_id': 3543316534,
#   'day': 0,
#   'id': 4224613223,
#   'items': 1750,
#   'total': 4.0},
#  {'customer_id': 3543316534,
#   'day': 0,
#   'id': 4224613223,
#   'items': 6458,
#   'total': 1.99},
#  {'customer_id': 3543316534,
#   'day': 0,
#   'id': 4224613223,
#   'items': 3776,
#   'total': 1.65},
#  {'customer_id': 3543316534,
#   'day': 0,
#   'id': 4224613223,
#   'items': 3776,
#   'total': 1.65},
#  {'customer_id': 3543316534,
#   'day': 0,
#   'id': 4224613223,
#   'items': 55757,
#   'total': 0.9},
#  {'customer_id': 3543316534,
#   'day': 0,
#   'id': 4224613223,
#   'items': 41109,
#   'total': 1.3},
#  {'customer_id': 3543316534,
#   'day': 0,
#   'id': 4224613223,
#   'items': 11726,
#   'total': 0.85},
#  {'customer_id': 3543316534,
#   'day': 0,
#   'id': 4224613223,
#   'items': 29082,
#   'total': 8.75},
#  {'customer_id': 1605758201,
#   'day': 0,
#   'id': 4018206091,
#   'items': 27732,
#   'total': 6.5},
#  {'customer_id': 1605758201,
#   'day': 0,
#   'id': 4018206091,
#   'items': 53646,
#   'total': 1.35},
#  {'customer_id': 1605758201,
#   'day': 0,
#   'id': 4018206091,
#   'items': 36126,
#   'total': 1.45},
#  {'customer_id': 1605758201,
#   'day': 0,
#   'id': 4018206091,
#   'items': 1584,
#   'total': 2.5},
#  {'customer_id': 958420868,
#   'day': 1,
#   'id': 1711613035,
#   'items': 59564,
#   'total': 1.2},
#  {'customer_id': 4036240255,
#   'day': 1,
#   'id': 2862852890,
#   'items': 3410,
#   'total': 1.0},
#  {'customer_id': 4036240255,
#   'day': 1,
#   'id': 2862852890,
#   'items': 35319,
#   'total': 1.5},
#  {'customer_id': 269896857,
#   'day': 1,
#   'id': 1178598170,
#   'items': 12543,
#   'total': 1.0},
#  {'customer_id': 269896857,
#   'day': 1,
#   'id': 1178598170,
#   'items': 52196,
#   'total': 2.9},
#  {'customer_id': 2493851942,
#   'day': 1,
#   'id': 2362707323,
#   'items': 25512,
#   'total': 1.0},
#  {'customer_id': 2493851942,
#   'day': 1,
#   'id': 2362707323,
#   'items': 62726,
#   'total': 1.75},
#  {'customer_id': 2493851942,
#   'day': 1,
#   'id': 2362707323,
#   'items': 52972,
#   'total': 1.2},
#  {'customer_id': 2493851942,
#   'day': 1,
#   'id': 2362707323,
#   'items': 5651,
#   'total': 1.48},
#  {'customer_id': 2493851942,
#   'day': 1,
#   'id': 2362707323,
#   'items': 39324,
#   'total': 2.85},
#  {'customer_id': 2493851942,
#   'day': 1,
#   'id': 2362707323,
#   'items': 39324,
#   'total': 2.85},
#  {'customer_id': 2493851942,
#   'day': 1,
#   'id': 2362707323,
#   'items': 41231,
#   'total': 3.75},
#  {'customer_id': 2493851942,
#   'day': 1,
#   'id': 2362707323,
#   'items': 27787,
#   'total': 1.1},
#  {'customer_id': 2493851942,
#   'day': 1,
#   'id': 2362707323,
#   'items': 1614,
#   'total': 3.5},
#  {'customer_id': 2493851942,
#   'day': 1,
#   'id': 2362707323,
#   'items': 43094,
#   'total': 1.5},
#  {'customer_id': 2493851942,
#   'day': 1,
#   'id': 2362707323,
#   'items': 885,
#   'total': 0.7000000000000001},
#  {'customer_id': 2493851942,
#   'day': 1,
#   'id': 2362707323,
#   'items': 18940,
#   'total': 3.5},
#  {'customer_id': 2493851942,
#   'day': 1,
#   'id': 2362707323,
#   'items': 19902,
#   'total': 1.0},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 57458,
#   'total': 0.55},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 54698,
#   'total': 1.0},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 26820,
#   'total': 1.35},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 25512,
#   'total': 1.0},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 60756,
#   'total': 0.8},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 25737,
#   'total': 1.5},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 42234,
#   'total': 0.6000000000000001},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 27376,
#   'total': 1.79},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 47439,
#   'total': 1.5},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 18633,
#   'total': 0.7000000000000001},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 43875,
#   'total': 1.0},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 35527,
#   'total': 0.6900000000000001},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 48607,
#   'total': 1.8},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 23858,
#   'total': 1.0},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 36088,
#   'total': 0.75},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 46063,
#   'total': 2.35},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 18633,
#   'total': 0.7000000000000001},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 13573,
#   'total': 2.5},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 35126,
#   'total': 1.5},
#  {'customer_id': 3006901239,
#   'day': 1,
#   'id': 2033902105,
#   'items': 31458,
#   'total': 1.5},
#  {'customer_id': 4079302491,
#   'day': 1,
#   'id': 770005046,
#   'items': 46027,
#   'total': 1.0},
#  {'customer_id': 4079302491,
#   'day': 1,
#   'id': 770005046,
#   'items': 23339,
#   'total': 1.0},
#  {'customer_id': 4079302491,
#   'day': 1,
#   'id': 770005046,
#   'items': 24737,
#   'total': 2.9},
#  {'customer_id': 4079302491,
#   'day': 1,
#   'id': 770005046,
#   'items': 23876,
#   'total': 1.13},
#  {'customer_id': 4079302491,
#   'day': 1,
#   'id': 770005046,
#   'items': 35773,
#   'total': 0.45},
#  {'customer_id': 4079302491,
#   'day': 1,
#   'id': 770005046,
#   'items': 6133,
#   'total': 1.77},
#  {'customer_id': 4079302491,
#   'day': 1,
#   'id': 770005046,
#   'items': 42234,
#   'total': 0.6000000000000001},
#  {'customer_id': 4079302491,
#   'day': 1,
#   'id': 770005046,
#   'items': 35527,
#   'total': 0.6900000000000001},
#  {'customer_id': 4079302491,
#   'day': 1,
#   'id': 770005046,
#   'items': 27610,
#   'total': 2.95},
#  {'customer_id': 4079302491,
#   'day': 1,
#   'id': 770005046,
#   'items': 41109,
#   'total': 1.3},
#  {'customer_id': 4079302491,
#   'day': 1,
#   'id': 770005046,
#   'items': 3410,
#   'total': 1.0},
#  {'customer_id': 4079302491,
#   'day': 1,
#   'id': 770005046,
#   'items': 31803,
#   'total': 10.49},
#  {'customer_id': 4079302491,
#   'day': 1,
#   'id': 770005046,
#   'items': 54442,
#   'total': 0.7000000000000001},
#  {'customer_id': 3594794604,
#   'day': 1,
#   'id': 3522046778,
#   'items': 13222,
#   'total': 1.3},
#  {'customer_id': 3594794604,
#   'day': 1,
#   'id': 3522046778,
#   'items': 41181,
#   'total': 2.0},
#  {'customer_id': 3594794604,
#   'day': 1,
#   'id': 3522046778,
#   'items': 42234,
#   'total': 0.6000000000000001},
#  {'customer_id': 3594794604,
#   'day': 1,
#   'id': 3522046778,
#   'items': 38204,
#   'total': 8.5},
#  {'customer_id': 3594794604,
#   'day': 1,
#   'id': 3522046778,
#   'items': 57525,
#   'total': 1.0},
#  {'customer_id': 3594794604,
#   'day': 1,
#   'id': 3522046778,
#   'items': 33464,
#   'total': 0.5},
#  {'customer_id': 3594794604,
#   'day': 1,
#   'id': 3522046778,
#   'items': 13413,
#   'total': 4.0},
#  {'customer_id': 3594794604,
#   'day': 1,
#   'id': 3522046778,
#   'items': 51974,
#   'total': 0.99},
#  {'customer_id': 1615855092,
#   'day': 1,
#   'id': 493171136,
#   'items': 44662,
#   'total': 4.5},
#  {'customer_id': 1615855092,
#   'day': 1,
#   'id': 493171136,
#   'items': 885,
#   'total': 0.7000000000000001},
#  {'customer_id': 1615855092,
#   'day': 1,
#   'id': 493171136,
#   'items': 13824,
#   'total': 1.48},
#  {'customer_id': 1615855092,
#   'day': 1,
#   'id': 493171136,
#   'items': 41371,
#   'total': 0.6000000000000001},
#  {'customer_id': 1615855092,
#   'day': 1,
#   'id': 493171136,
#   'items': 26820,
#   'total': 1.35},
#  {'customer_id': 1615855092,
#   'day': 1,
#   'id': 493171136,
#   'items': 39686,
#   'total': 0.68},
#  {'customer_id': 1615855092,
#   'day': 1,
#   'id': 493171136,
#   'items': 48274,
#   'total': 1.85},
#  {'customer_id': 1615855092,
#   'day': 1,
#   'id': 493171136,
#   'items': 32,
#   'total': 1.4},
#  {'customer_id': 1615855092,
#   'day': 1,
#   'id': 493171136,
#   'items': 35773,
#   'total': 0.45},
#  {'customer_id': 1615855092,
#   'day': 1,
#   'id': 493171136,
#   'items': 41069,
#   'total': 3.5},
#  {'customer_id': 250142846,
#   'day': 1,
#   'id': 396381479,
#   'items': 7737,
#   'total': 1.5},
#  {'customer_id': 250142846,
#   'day': 1,
#   'id': 396381479,
#   'items': 63381,
#   'total': 0.45},
#  {'customer_id': 250142846,
#   'day': 1,
#   'id': 396381479,
#   'items': 37577,
#   'total': 0.85},
#  {'customer_id': 250142846,
#   'day': 1,
#   'id': 396381479,
#   'items': 25070,
#   'total': 1.3},
#  {'customer_id': 250142846,
#   'day': 1,
#   'id': 396381479,
#   'items': 62726,
#   'total': 1.75},
#  {'customer_id': 250142846,
#   'day': 1,
#   'id': 396381479,
#   'items': 53728,
#   'total': 1.1},
#  {'customer_id': 250142846,
#   'day': 1,
#   'id': 396381479,
#   'items': 54442,
#   'total': 0.7000000000000001},
#  {'customer_id': 250142846,
#   'day': 1,
#   'id': 396381479,
#   'items': 26558,
#   'total': 1.25},
#  {'customer_id': 250142846,
#   'day': 1,
#   'id': 396381479,
#   'items': 39686,
#   'total': 0.68},
#  {'customer_id': 250142846,
#   'day': 1,
#   'id': 396381479,
#   'items': 54600,
#   'total': 3.0},
#  {'customer_id': 958420868,
#   'day': 2,
#   'id': 834041495,
#   'items': 1750,
#   'total': 4.0},
#  {'customer_id': 4036240255,
#   'day': 2,
#   'id': 3408511679,
#   'items': 28174,
#   'total': 2.0},
#  {'customer_id': 269896857,
#   'day': 2,
#   'id': 3485463160,
#   'items': 1614,
#   'total': 3.5},
#  {'customer_id': 3031153441,
#   'day': 2,
#   'id': 2809861288,
#   'items': 30113,
#   'total': 1.9500000000000002},
#  {'customer_id': 3031153441,
#   'day': 2,
#   'id': 2809861288,
#   'items': 28474,
#   'total': 1.5},
#  {'customer_id': 3031153441,
#   'day': 2,
#   'id': 2809861288,
#   'items': 43632,
#   'total': 2.5},
#  {'customer_id': 3031153441,
#   'day': 2,
#   'id': 2809861288,
#   'items': 10921,
#   'total': 1.5},
#  {'customer_id': 3031153441,
#   'day': 2,
#   'id': 2809861288,
#   'items': 885,
#   'total': 0.7000000000000001},
#  {'customer_id': 3031153441,
#   'day': 2,
#   'id': 2809861288,
#   'items': 28174,
#   'total': 2.0},
#  {'customer_id': 3031153441,
#   'day': 2,
#   'id': 2809861288,
#   'items': 3776,
#   'total': 1.65},
#  {'customer_id': 3031153441,
#   'day': 2,
#   'id': 2809861288,
#   'items': 27376,
#   'total': 1.79},
#  {'customer_id': 3031153441,
#   'day': 2,
#   'id': 2809861288,
#   'items': 26352,
#   'total': 2.0},
#  {'customer_id': 3031153441,
#   'day': 2,
#   'id': 2809861288,
#   'items': 37445,
#   'total': 1.0},
#  {'customer_id': 3031153441,
#   'day': 2,
#   'id': 2809861288,
#   'items': 46636,
#   'total': 3.65},
#  {'customer_id': 3031153441,
#   'day': 2,
#   'id': 2809861288,
#   'items': 39584,
#   'total': 2.25},
#  {'customer_id': 3031153441,
#   'day': 2,
#   'id': 2809861288,
#   'items': 47290,
#   'total': 0.30000000000000004},
#  {'customer_id': 3031153441,
#   'day': 2,
#   'id': 2809861288,
#   'items': 36057,
#   'total': 0.65},
#  {'customer_id': 2630012468,
#   'day': 2,
#   'id': 1588363933,
#   'items': 52196,
#   'total': 2.9},
#  {'customer_id': 2630012468,
#   'day': 2,
#   'id': 1588363933,
#   'items': 6458,
#   'total': 1.99},
#  {'customer_id': 2630012468,
#   'day': 2,
#   'id': 1588363933,
#   'items': 15694,
#   'total': 5.5},
#  {'customer_id': 2630012468,
#   'day': 2,
#   'id': 1588363933,
#   'items': 41765,
#   'total': 1.5},
#  {'customer_id': 2630012468,
#   'day': 2,
#   'id': 1588363933,
#   'items': 7969,
#   'total': 2.35},
#  {'customer_id': 2630012468,
#   'day': 2,
#   'id': 1588363933,
#   'items': 56792,
#   'total': 1.65},
#  {'customer_id': 2630012468,
#   'day': 2,
#   'id': 1588363933,
#   'items': 28451,
#   'total': 0.55},
#  {'customer_id': 2630012468,
#   'day': 2,
#   'id': 1588363933,
#   'items': 35731,
#   'total': 6.0},
#  {'customer_id': 2630012468,
#   'day': 2,
#   'id': 1588363933,
#   'items': 50775,
#   'total': 0.6900000000000001},
#  {'customer_id': 2630012468,
#   'day': 2,
#   'id': 1588363933,
#   'items': 43391,
#   'total': 0.98},
#  {'customer_id': 2630012468,
#   'day': 2,
#   'id': 1588363933,
#   'items': 12543,
#   'total': 1.0},
#  {'customer_id': 2630012468,
#   'day': 2,
#   'id': 1588363933,
#   'items': 37577,
#   'total': 0.85},
#  {'customer_id': 3325278451,
#   'day': 2,
#   'id': 1379144135,
#   'items': 48361,
#   'total': 0.85},
#  {'customer_id': 3325278451,
#   'day': 2,
#   'id': 1379144135,
#   'items': 41428,
#   'total': 2.2},
#  {'customer_id': 3325278451,
#   'day': 2,
#   'id': 1379144135,
#   'items': 8309,
#   'total': 1.77},
#  {'customer_id': 3325278451,
#   'day': 2,
#   'id': 1379144135,
#   'items': 41109,
#   'total': 1.3},
#  {'customer_id': 3325278451,
#   'day': 2,
#   'id': 1379144135,
#   'items': 45061,
#   'total': 0.85},
#  {'customer_id': 3325278451,
#   'day': 2,
#   'id': 1379144135,
#   'items': 20301,
#   'total': 1.3},
#  {'customer_id': 3325278451,
#   'day': 2,
#   'id': 1379144135,
#   'items': 33067,
#   'total': 0.9},
#  {'customer_id': 3325278451,
#   'day': 2,
#   'id': 1379144135,
#   'items': 41069,
#   'total': 3.5},
#  {'customer_id': 761977121,
#   'day': 2,
#   'id': 3960942960,
#   'items': 41069,
#   'total': 3.5},
#  {'customer_id': 761977121,
#   'day': 2,
#   'id': 3960942960,
#   'items': 49522,
#   'total': 0.99},
#  {'customer_id': 761977121,
#   'day': 2,
#   'id': 3960942960,
#   'items': 4284,
#   'total': 2.48},
#  {'customer_id': 761977121,
#   'day': 2,
#   'id': 3960942960,
#   'items': 5049,
#   'total': 0.5},
#  {'customer_id': 761977121,
#   'day': 2,
#   'id': 3960942960,
#   'items': 1614,
#   'total': 3.5},
#  {'customer_id': 761977121,
#   'day': 2,
#   'id': 3960942960,
#   'items': 15694,
#   'total': 5.5},
#  {'customer_id': 761977121,
#   'day': 2,
#   'id': 3960942960,
#   'items': 11726,
#   'total': 0.85},
#  {'customer_id': 761977121,
#   'day': 2,
#   'id': 3960942960,
#   'items': 46067,
#   'total': 3.1},
#  {'customer_id': 761977121,
#   'day': 2,
#   'id': 3960942960,
#   'items': 42234,
#   'total': 0.6000000000000001},
#  {'customer_id': 761977121,
#   'day': 2,
#   'id': 3960942960,
#   'items': 51974,
#   'total': 0.99},
#  {'customer_id': 761977121,
#   'day': 2,
#   'id': 3960942960,
#   'items': 51974,
#   'total': 0.99},
#  {'customer_id': 761977121,
#   'day': 2,
#   'id': 3960942960,
#   'items': 24832,
#   'total': 0.9500000000000001},
#  {'customer_id': 761977121,
#   'day': 2,
#   'id': 3960942960,
#   'items': 54698,
#   'total': 1.0},
#  {'customer_id': 761977121,
#   'day': 2,
#   'id': 3960942960,
#   'items': 16846,
#   'total': 1.0},
#  {'customer_id': 2041761052,
#   'day': 2,
#   'id': 1794521171,
#   'items': 52022,
#   'total': 2.0},
#  {'customer_id': 2041761052,
#   'day': 2,
#   'id': 1794521171,
#   'items': 15921,
#   'total': 0.6000000000000001},
#  {'customer_id': 2041761052,
#   'day': 2,
#   'id': 1794521171,
#   'items': 23587,
#   'total': 1.5},
#  {'customer_id': 2041761052,
#   'day': 2,
#   'id': 1794521171,
#   'items': 15555,
#   'total': 0.65},
#  {'customer_id': 2041761052,
#   'day': 2,
#   'id': 1794521171,
#   'items': 46366,
#   'total': 3.0},
#  {'customer_id': 2041761052,
#   'day': 2,
#   'id': 1794521171,
#   'items': 60151,
#   'total': 9.75},
#  {'customer_id': 2041761052,
#   'day': 2,
#   'id': 1794521171,
#   'items': 46547,
#   'total': 1.6},
#  {'customer_id': 2326982145,
#   'day': 2,
#   'id': 916023520,
#   'items': 29284,
#   'total': 2.0},
#  {'customer_id': 2326982145,
#   'day': 2,
#   'id': 916023520,
#   'items': 23056,
#   'total': 0.6900000000000001},
#  {'customer_id': 2326982145,
#   'day': 2,
#   'id': 916023520,
#   'items': 18736,
#   'total': 9.5},
#  {'customer_id': 2326982145,
#   'day': 2,
#   'id': 916023520,
#   'items': 56792,
#   'total': 1.65},
#  {'customer_id': 2326982145,
#   'day': 2,
#   'id': 916023520,
#   'items': 3776,
#   'total': 1.65},
#  {'customer_id': 2326982145,
#   'day': 2,
#   'id': 916023520,
#   'items': 12388,
#   'total': 2.0},
#  {'customer_id': 2326982145,
#   'day': 2,
#   'id': 916023520,
#   'items': 57525,
#   'total': 1.0},
#  {'customer_id': 2326982145,
#   'day': 2,
#   'id': 916023520,
#   'items': 6133,
#   'total': 1.77},
#  {'customer_id': 2326982145,
#   'day': 2,
#   'id': 916023520,
#   'items': 46027,
#   'total': 1.0},
#  {'customer_id': 2326982145,
#   'day': 2,
#   'id': 916023520,
#   'items': 26558,
#   'total': 1.25},
#  {'customer_id': 2326982145,
#   'day': 2,
#   'id': 916023520,
#   'items': 53432,
#   'total': 1.45},
#  {'customer_id': 2326982145,
#   'day': 2,
#   'id': 916023520,
#   'items': 21511,
#   'total': 1.46},
#  {'customer_id': 3444299591,
#   'day': 2,
#   'id': 1640340900,
#   'items': 42885,
#   'total': 1.9},
#  {'customer_id': 3444299591,
#   'day': 2,
#   'id': 1640340900,
#   'items': 41218,
#   'total': 1.3},
#  {'customer_id': 3444299591,
#   'day': 2,
#   'id': 1640340900,
#   'items': 35319,
#   'total': 1.5},
#  {'customer_id': 3444299591,
#   'day': 2,
#   'id': 1640340900,
#   'items': 19902,
#   'total': 1.0},
#  {'customer_id': 3444299591,
#   'day': 2,
#   'id': 1640340900,
#   'items': 6954,
#   'total': 3.75},
#  {'customer_id': 3444299591,
#   'day': 2,
#   'id': 1640340900,
#   'items': 14667,
#   'total': 8.5},
#  {'customer_id': 3444299591,
#   'day': 2,
#   'id': 1640340900,
#   'items': 4367,
#   'total': 0.75},
#  {'customer_id': 3444299591,
#   'day': 2,
#   'id': 1640340900,
#   'items': 17440,
#   'total': 1.25},
#  {'customer_id': 3444299591,
#   'day': 2,
#   'id': 1640340900,
#   'items': 53646,
#   'total': 1.35},
#  {'customer_id': 3444299591,
#   'day': 2,
#   'id': 1640340900,
#   'items': 49701,
#   'total': 2.0},
#  {'customer_id': 958420868,
#   'day': 3,
#   'id': 2789801814,
#   'items': 46980,
#   'total': 1.75},
#  {'customer_id': 4036240255,
#   'day': 3,
#   'id': 3665013674,
#   'items': 52269,
#   'total': 1.0},
#  {'customer_id': 269896857,
#   'day': 3,
#   'id': 2143692990,
#   'items': 27787,
#   'total': 1.1},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 23858,
#   'total': 1.0},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 26352,
#   'total': 2.0},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 48361,
#   'total': 0.85},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 7244,
#   'total': 0.79},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 42405,
#   'total': 0.99},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 52171,
#   'total': 0.6000000000000001},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 54698,
#   'total': 1.0},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 552,
#   'total': 7.0},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 25737,
#   'total': 1.5},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 5049,
#   'total': 0.5},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 47290,
#   'total': 0.30000000000000004},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 4284,
#   'total': 2.48},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 42405,
#   'total': 0.99},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 39686,
#   'total': 0.68},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 35566,
#   'total': 1.0},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 57525,
#   'total': 1.0},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 26335,
#   'total': 0.7000000000000001},
#  {'customer_id': 961301073,
#   'day': 3,
#   'id': 3926609346,
#   'items': 41181,
#   'total': 2.0},
#  {'customer_id': 2546376173,
#   'day': 3,
#   'id': 4100900238,
#   'items': 59734,
#   'total': 1.0},
#  {'customer_id': 2546376173,
#   'day': 3,
#   'id': 4100900238,
#   'items': 23587,
#   'total': 1.5},
#  {'customer_id': 2546376173,
#   'day': 3,
#   'id': 4100900238,
#   'items': 8309,
#   'total': 1.77},
#  {'customer_id': 2546376173,
#   'day': 3,
#   'id': 4100900238,
#   'items': 36088,
#   'total': 0.75},
#  {'customer_id': 2546376173,
#   'day': 3,
#   'id': 4100900238,
#   'items': 53728,
#   'total': 1.1},
#  {'customer_id': 2546376173,
#   'day': 3,
#   'id': 4100900238,
#   'items': 44662,
#   'total': 4.5},
#  {'customer_id': 2546376173,
#   'day': 3,
#   'id': 4100900238,
#   'items': 52529,
#   'total': 0.9},
#  {'customer_id': 2546376173,
#   'day': 3,
#   'id': 4100900238,
#   'items': 5049,
#   'total': 0.5},
#  {'customer_id': 2546376173,
#   'day': 3,
#   'id': 4100900238,
#   'items': 6133,
#   'total': 1.77},
#  {'customer_id': 2546376173,
#   'day': 3,
#   'id': 4100900238,
#   'items': 54600,
#   'total': 3.0},
#  {'customer_id': 2546376173,
#   'day': 3,
#   'id': 4100900238,
#   'items': 63594,
#   'total': 1.46},
#  {'customer_id': 2546376173,
#   'day': 3,
#   'id': 4100900238,
#   'items': 37445,
#   'total': 1.0},
#  {'customer_id': 2546376173,
#   'day': 3,
#   'id': 4100900238,
#   'items': 46067,
#   'total': 3.1},
#  {'customer_id': 2546376173,
#   'day': 3,
#   'id': 4100900238,
#   'items': 25652,
#   'total': 1.46},
#  {'customer_id': 2546376173,
#   'day': 3,
#   'id': 4100900238,
#   'items': 64051,
#   'total': 1.2},
#  {'customer_id': 915486375,
#   'day': 3,
#   'id': 4228873302,
#   'items': 2846,
#   'total': 2.95},
#  {'customer_id': 915486375,
#   'day': 3,
#   'id': 4228873302,
#   'items': 57085,
#   'total': 4.5},
#  {'customer_id': 915486375,
#   'day': 3,
#   'id': 4228873302,
#   'items': 6133,
#   'total': 1.77},
#  {'customer_id': 915486375,
#   'day': 3,
#   'id': 4228873302,
#   'items': 62913,
#   'total': 1.8},
#  {'customer_id': 915486375,
#   'day': 3,
#   'id': 4228873302,
#   'items': 18016,
#   'total': 1.3},
#  {'customer_id': 915486375,
#   'day': 3,
#   'id': 4228873302,
#   'items': 13573,
#   'total': 2.5},
#  {'customer_id': 915486375,
#   'day': 3,
#   'id': 4228873302,
#   'items': 28474,
#   'total': 1.5},
#  {'customer_id': 915486375,
#   'day': 3,
#   'id': 4228873302,
#   'items': 54442,
#   'total': 0.7000000000000001},
#  {'customer_id': 915486375,
#   'day': 3,
#   'id': 4228873302,
#   'items': 2172,
#   'total': 7.0},
#  {'customer_id': 915486375,
#   'day': 3,
#   'id': 4228873302,
#   'items': 3431,
#   'total': 0.9500000000000001},
#  {'customer_id': 532895532,
#   'day': 3,
#   'id': 3138040467,
#   'items': 25592,
#   'total': 1.0},
#  {'customer_id': 532895532,
#   'day': 3,
#   'id': 3138040467,
#   'items': 64051,
#   'total': 1.2},
#  {'customer_id': 958420868,
#   'day': 4,
#   'id': 713399524,
#   'items': 52120,
#   'total': 1.03},
#  {'customer_id': 958420868,
#   'day': 4,
#   'id': 713399524,
#   'items': 13222,
#   'total': 1.3},
#  {'customer_id': 958420868,
#   'day': 4,
#   'id': 713399524,
#   'items': 7244,
#   'total': 0.79},
#  {'customer_id': 4036240255,
#   'day': 4,
#   'id': 294379552,
#   'items': 20944,
#   'total': 1.5},
#  {'customer_id': 4036240255,
#   'day': 4,
#   'id': 294379552,
#   'items': 34797,
#   'total': 2.5},
#  {'customer_id': 269896857,
#   'day': 4,
#   'id': 666346321,
#   'items': 11726,
#   'total': 0.85},
#  {'customer_id': 269896857,
#   'day': 4,
#   'id': 666346321,
#   'items': 23479,
#   'total': 0.35000000000000003},
#  {'customer_id': 269896857,
#   'day': 4,
#   'id': 666346321,
#   'items': 22633,
#   'total': 1.9},
#  {'customer_id': 3745847835,
#   'day': 4,
#   'id': 1763905032,
#   'items': 39962,
#   'total': 1.65},
#  {'customer_id': 3745847835,
#   'day': 4,
#   'id': 1763905032,
#   'items': 36126,
#   'total': 1.45},
#  {'customer_id': 3745847835,
#   'day': 4,
#   'id': 1763905032,
#   'items': 46636,
#   'total': 3.65},
#  {'customer_id': 3745847835,
#   'day': 4,
#   'id': 1763905032,
#   'items': 54369,
#   'total': 11.0},
#  {'customer_id': 3745847835,
#   'day': 4,
#   'id': 1763905032,
#   'items': 13009,
#   'total': 1.46},
#  {'customer_id': 3745847835,
#   'day': 4,
#   'id': 1763905032,
#   'items': 13573,
#   'total': 2.5},
#  {'customer_id': 3745847835,
#   'day': 4,
#   'id': 1763905032,
#   'items': 46636,
#   'total': 3.65},
#  {'customer_id': 789231310,
#   'day': 4,
#   'id': 1965973243,
#   'items': 12543,
#   'total': 1.0},
#  {'customer_id': 789231310,
#   'day': 4,
#   'id': 1965973243,
#   'items': 55439,
#   'total': 7.0},
#  {'customer_id': 789231310,
#   'day': 4,
#   'id': 1965973243,
#   'items': 10132,
#   'total': 1.3},
#  {'customer_id': 789231310,
#   'day': 4,
#   'id': 1965973243,
#   'items': 26335,
#   'total': 0.7000000000000001},
#  {'customer_id': 789231310,
#   'day': 4,
#   'id': 1965973243,
#   'items': 57769,
#   'total': 1.0},
#  {'customer_id': 789231310,
#   'day': 4,
#   'id': 1965973243,
#   'items': 4367,
#   'total': 0.75},
#  {'customer_id': 789231310,
#   'day': 4,
#   'id': 1965973243,
#   'items': 23339,
#   'total': 1.0},
#  {'customer_id': 789231310,
#   'day': 4,
#   'id': 1965973243,
#   'items': 23711,
#   'total': 9.5},
#  {'customer_id': 789231310,
#   'day': 4,
#   'id': 1965973243,
#   'items': 15921,
#   'total': 0.6000000000000001},
#  {'customer_id': 789231310,
#   'day': 4,
#   'id': 1965973243,
#   'items': 27376,
#   'total': 1.79},
#  {'customer_id': 789231310,
#   'day': 4,
#   'id': 1965973243,
#   'items': 52120,
#   'total': 1.03},
#  {'customer_id': 683775536,
#   'day': 4,
#   'id': 4104190193,
#   'items': 35319,
#   'total': 1.5},
#  {'customer_id': 683775536,
#   'day': 4,
#   'id': 4104190193,
#   'items': 64782,
#   'total': 1.15},
#  {'customer_id': 683775536,
#   'day': 4,
#   'id': 4104190193,
#   'items': 52972,
#   'total': 1.2},
#  {'customer_id': 683775536,
#   'day': 4,
#   'id': 4104190193,
#   'items': 23056,
#   'total': 0.6900000000000001},
#  {'customer_id': 683775536,
#   'day': 4,
#   'id': 4104190193,
#   'items': 29082,
#   'total': 8.75},
#  {'customer_id': 683775536,
#   'day': 4,
#   'id': 4104190193,
#   'items': 18633,
#   'total': 0.7000000000000001},
#  {'customer_id': 683775536,
#   'day': 4,
#   'id': 4104190193,
#   'items': 57458,
#   'total': 0.55},
#  {'customer_id': 683775536,
#   'day': 4,
#   'id': 4104190193,
#   'items': 46067,
#   'total': 3.1},
#  {'customer_id': 683775536,
#   'day': 4,
#   'id': 4104190193,
#   'items': 53728,
#   'total': 1.1},
#  {'customer_id': 683775536,
#   'day': 4,
#   'id': 4104190193,
#   'items': 17910,
#   'total': 1.15},
#  {'customer_id': 683775536,
#   'day': 4,
#   'id': 4104190193,
#   'items': 27610,
#   'total': 2.95},
#  {'customer_id': 2262950664,
#   'day': 4,
#   'id': 4136616405,
#   'items': 25652,
#   'total': 1.46},
#  {'customer_id': 2262950664,
#   'day': 4,
#   'id': 4136616405,
#   'items': 17670,
#   'total': 1.0},
#  {'customer_id': 2262950664,
#   'day': 4,
#   'id': 4136616405,
#   'items': 26820,
#   'total': 1.35},
#  {'customer_id': 2262950664,
#   'day': 4,
#   'id': 4136616405,
#   'items': 23339,
#   'total': 1.0},
#  {'customer_id': 2262950664,
#   'day': 4,
#   'id': 4136616405,
#   'items': 12543,
#   'total': 1.0},
#  {'customer_id': 2262950664,
#   'day': 4,
#   'id': 4136616405,
#   'items': 29284,
#   'total': 2.0},
#  {'customer_id': 2262950664,
#   'day': 4,
#   'id': 4136616405,
#   'items': 55757,
#   'total': 0.9},
#  {'customer_id': 2262950664,
#   'day': 4,
#   'id': 4136616405,
#   'items': 37577,
#   'total': 0.85},
#  {'customer_id': 2262950664,
#   'day': 4,
#   'id': 4136616405,
#   'items': 35527,
#   'total': 0.6900000000000001},
#  {'customer_id': 2262950664,
#   'day': 4,
#   'id': 4136616405,
#   'items': 45061,
#   'total': 0.85},
#  {'customer_id': 2262950664,
#   'day': 4,
#   'id': 4136616405,
#   'items': 6458,
#   'total': 1.99},
#  {'customer_id': 2262950664,
#   'day': 4,
#   'id': 4136616405,
#   'items': 24832,
#   'total': 0.9500000000000001},
#  {'customer_id': 2262950664,
#   'day': 4,
#   'id': 4136616405,
#   'items': 3628,
#   'total': 0.85},
#  {'customer_id': 2262950664,
#   'day': 4,
#   'id': 4136616405,
#   'items': 57085,
#   'total': 4.5},
#  {'customer_id': 109759433,
#   'day': 4,
#   'id': 3732328296,
#   'items': 54600,
#   'total': 3.0},
#  {'customer_id': 109759433,
#   'day': 4,
#   'id': 3732328296,
#   'items': 20944,
#   'total': 1.5},
#  {'customer_id': 109759433,
#   'day': 4,
#   'id': 3732328296,
#   'items': 7737,
#   'total': 1.5},
#  {'customer_id': 109759433,
#   'day': 4,
#   'id': 3732328296,
#   'items': 28275,
#   'total': 1.46},
#  {'customer_id': 109759433,
#   'day': 4,
#   'id': 3732328296,
#   'items': 25512,
#   'total': 1.0},
#  {'customer_id': 109759433,
#   'day': 4,
#   'id': 3732328296,
#   'items': 28285,
#   'total': 10.8},
#  {'customer_id': 952267414,
#   'day': 4,
#   'id': 1581625708,
#   'items': 13484,
#   'total': 3.5},
#  {'customer_id': 952267414,
#   'day': 4,
#   'id': 1581625708,
#   'items': 20301,
#   'total': 1.3},
#  {'customer_id': 952267414,
#   'day': 4,
#   'id': 1581625708,
#   'items': 38518,
#   'total': 3.0},
#  {'customer_id': 952267414,
#   'day': 4,
#   'id': 1581625708,
#   'items': 1750,
#   'total': 4.0},
#  {'customer_id': 952267414,
#   'day': 4,
#   'id': 1581625708,
#   'items': 39702,
#   'total': 3.0},
#  {'customer_id': 603295827,
#   'day': 4,
#   'id': 590038179,
#   'items': 30026,
#   'total': 1.0},
#  {'customer_id': 603295827,
#   'day': 4,
#   'id': 590038179,
#   'items': 47290,
#   'total': 0.30000000000000004},
#  {'customer_id': 603295827,
#   'day': 4,
#   'id': 590038179,
#   'items': 1960,
#   'total': 1.79},
#  {'customer_id': 603295827,
#   'day': 4,
#   'id': 590038179,
#   'items': 60151,
#   'total': 9.75},
#  {'customer_id': 603295827,
#   'day': 4,
#   'id': 590038179,
#   'items': 36126,
#   'total': 1.45},
#  {'customer_id': 603295827,
#   'day': 4,
#   'id': 590038179,
#   'items': 62726,
#   'total': 1.75},
#  {'customer_id': 603295827,
#   'day': 4,
#   'id': 590038179,
#   'items': 28174,
#   'total': 2.0},
#  {'customer_id': 603295827,
#   'day': 4,
#   'id': 590038179,
#   'items': 10132,
#   'total': 1.3},
#  {'customer_id': 603295827,
#   'day': 4,
#   'id': 590038179,
#   'items': 48274,
#   'total': 1.85},
#  {'customer_id': 603295827,
#   'day': 4,
#   'id': 590038179,
#   'items': 1614,
#   'total': 3.5},
#  {'customer_id': 106098987,
#   'day': 4,
#   'id': 654409269,
#   'items': 13824,
#   'total': 1.48},
#  {'customer_id': 106098987,
#   'day': 4,
#   'id': 654409269,
#   'items': 14679,
#   'total': 0.6000000000000001},
#  {'customer_id': 106098987,
#   'day': 4,
#   'id': 654409269,
#   'items': 64049,
#   'total': 1.0},
#  {'customer_id': 106098987,
#   'day': 4,
#   'id': 654409269,
#   'items': 6796,
#   'total': 12.0},
#  {'customer_id': 106098987,
#   'day': 4,
#   'id': 654409269,
#   'items': 17707,
#   'total': 4.0},
#  {'customer_id': 106098987,
#   'day': 4,
#   'id': 654409269,
#   'items': 46636,
#   'total': 3.65},
#  {'customer_id': 106098987,
#   'day': 4,
#   'id': 654409269,
#   'items': 8334,
#   'total': 1.5},
#  {'customer_id': 958420868,
#   'day': 5,
#   'id': 3866877131,
#   'items': 39702,
#   'total': 3.0},
#  {'customer_id': 4036240255,
#   'day': 5,
#   'id': 3236238941,
#   'items': 5651,
#   'total': 1.48},
#  {'customer_id': 4036240255,
#   'day': 5,
#   'id': 3236238941,
#   'items': 12543,
#   'total': 1.0},
#  {'customer_id': 4036240255,
#   'day': 5,
#   'id': 3236238941,
#   'items': 25512,
#   'total': 1.0},
#  {'customer_id': 269896857,
#   'day': 5,
#   'id': 74016329,
#   'items': 8560,
#   'total': 3.0},
#  {'customer_id': 464317747,
#   'day': 5,
#   'id': 721713652,
#   'items': 25652,
#   'total': 1.46},
#  {'customer_id': 464317747,
#   'day': 5,
#   'id': 721713652,
#   'items': 11836,
#   'total': 2.0},
#  {'customer_id': 464317747,
#   'day': 5,
#   'id': 721713652,
#   'items': 32306,
#   'total': 0.6000000000000001},
#  {'customer_id': 464317747,
#   'day': 5,
#   'id': 721713652,
#   'items': 3776,
#   'total': 1.65},
#  {'customer_id': 464317747,
#   'day': 5,
#   'id': 721713652,
#   'items': 6458,
#   'total': 1.99},
#  {'customer_id': 464317747,
#   'day': 5,
#   'id': 721713652,
#   'items': 1614,
#   'total': 3.5},
#  {'customer_id': 464317747,
#   'day': 5,
#   'id': 721713652,
#   'items': 52381,
#   'total': 1.25},
#  {'customer_id': 464317747,
#   'day': 5,
#   'id': 721713652,
#   'items': 62913,
#   'total': 1.8},
#  {'customer_id': 464317747,
#   'day': 5,
#   'id': 721713652,
#   'items': 35319,
#   'total': 1.5},
#  {'customer_id': 464317747,
#   'day': 5,
#   'id': 721713652,
#   'items': 6954,
#   'total': 3.75},
#  {'customer_id': 464317747,
#   'day': 5,
#   'id': 721713652,
#   'items': 12388,
#   'total': 2.0},
#  {'customer_id': 464317747,
#   'day': 5,
#   'id': 721713652,
#   'items': 6133,
#   'total': 1.77},
#  {'customer_id': 464317747,
#   'day': 5,
#   'id': 721713652,
#   'items': 52022,
#   'total': 2.0},
#  {'customer_id': 3982346988,
#   'day': 5,
#   'id': 1857809963,
#   'items': 46225,
#   'total': 1.7000000000000002},
#  {'customer_id': 3982346988,
#   'day': 5,
#   'id': 1857809963,
#   'items': 52171,
#   'total': 0.6000000000000001},
#  {'customer_id': 3982346988,
#   'day': 5,
#   'id': 1857809963,
#   'items': 8557,
#   'total': 2.0},
#  {'customer_id': 3982346988,
#   'day': 5,
#   'id': 1857809963,
#   'items': 4227,
#   'total': 16.0},
#  {'customer_id': 3982346988,
#   'day': 5,
#   'id': 1857809963,
#   'items': 1584,
#   'total': 2.5},
#  {'customer_id': 3982346988,
#   'day': 5,
#   'id': 1857809963,
#   'items': 39962,
#   'total': 1.65},
#  {'customer_id': 17985943,
#   'day': 5,
#   'id': 1181139264,
#   'items': 7737,
#   'total': 1.5},
#  {'customer_id': 17985943,
#   'day': 5,
#   'id': 1181139264,
#   'items': 43391,
#   'total': 0.98},
#  {'customer_id': 17985943,
#   'day': 5,
#   'id': 1181139264,
#   'items': 18633,
#   'total': 0.7000000000000001},
#  {'customer_id': 17985943,
#   'day': 5,
#   'id': 1181139264,
#   'items': 13484,
#   'total': 3.5},
#  {'customer_id': 17985943,
#   'day': 5,
#   'id': 1181139264,
#   'items': 35319,
#   'total': 1.5},
#  {'customer_id': 17985943,
#   'day': 5,
#   'id': 1181139264,
#   'items': 57741,
#   'total': 0.43},
#  {'customer_id': 17985943,
#   'day': 5,
#   'id': 1181139264,
#   'items': 53646,
#   'total': 1.35},
#  {'customer_id': 17985943,
#   'day': 5,
#   'id': 1181139264,
#   'items': 27732,
#   'total': 6.5},
#  {'customer_id': 17985943,
#   'day': 5,
#   'id': 1181139264,
#   'items': 52269,
#   'total': 1.0},
#  {'customer_id': 17985943,
#   'day': 5,
#   'id': 1181139264,
#   'items': 17440,
#   'total': 1.25},
#  {'customer_id': 17985943,
#   'day': 5,
#   'id': 1181139264,
#   'items': 17670,
#   'total': 1.0},
#  {'customer_id': 17985943,
#   'day': 5,
#   'id': 1181139264,
#   'items': 51583,
#   'total': 1.45},
#  {'customer_id': 17985943,
#   'day': 5,
#   'id': 1181139264,
#   'items': 46636,
#   'total': 3.65},
#  {'customer_id': 17985943,
#   'day': 5,
#   'id': 1181139264,
#   'items': 25652,
#   'total': 1.46},
#  {'customer_id': 1161697091,
#   'day': 5,
#   'id': 3859513325,
#   'items': 51583,
#   'total': 1.45},
#  {'customer_id': 1161697091,
#   'day': 5,
#   'id': 3859513325,
#   'items': 54369,
#   'total': 11.0},
#  {'customer_id': 1161697091,
#   'day': 5,
#   'id': 3859513325,
#   'items': 24958,
#   'total': 3.0},
#  {'customer_id': 1161697091,
#   'day': 5,
#   'id': 3859513325,
#   'items': 17707,
#   'total': 4.0},
#  {'customer_id': 1161697091,
#   'day': 5,
#   'id': 3859513325,
#   'items': 3431,
#   'total': 0.9500000000000001},
#  {'customer_id': 1161697091,
#   'day': 5,
#   'id': 3859513325,
#   'items': 59580,
#   'total': 3.75},
#  {'customer_id': 1161697091,
#   'day': 5,
#   'id': 3859513325,
#   'items': 32,
#   'total': 1.4},
#  {'customer_id': 4080807039,
#   'day': 5,
#   'id': 1395817282,
#   'items': 53646,
#   'total': 1.35},
#  {'customer_id': 4080807039,
#   'day': 5,
#   'id': 1395817282,
#   'items': 25737,
#   'total': 1.5},
#  {'customer_id': 4080807039,
#   'day': 5,
#   'id': 1395817282,
#   'items': 25737,
#   'total': 1.5},
#  {'customer_id': 4080807039,
#   'day': 5,
#   'id': 1395817282,
#   'items': 33533,
#   'total': 0.7000000000000001},
#  {'customer_id': 4080807039,
#   'day': 5,
#   'id': 1395817282,
#   'items': 17440,
#   'total': 1.25},
#  {'customer_id': 4080807039,
#   'day': 5,
#   'id': 1395817282,
#   'items': 39193,
#   'total': 4.25},
#  {'customer_id': 4080807039,
#   'day': 5,
#   'id': 1395817282,
#   'items': 63381,
#   'total': 0.45},
#  {'customer_id': 4080807039,
#   'day': 5,
#   'id': 1395817282,
#   'items': 48466,
#   'total': 7.6},
#  {'customer_id': 4080807039,
#   'day': 5,
#   'id': 1395817282,
#   'items': 41231,
#   'total': 3.75},
#  {'customer_id': 4080807039,
#   'day': 5,
#   'id': 1395817282,
#   'items': 28451,
#   'total': 0.55},
#  {'customer_id': 4080807039,
#   'day': 5,
#   'id': 1395817282,
#   'items': 55306,
#   'total': 2.0},
#  {'customer_id': 4080807039,
#   'day': 5,
#   'id': 1395817282,
#   'items': 36381,
#   'total': 1.25},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 16846,
#   'total': 1.0},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 41181,
#   'total': 2.0},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 2648,
#   'total': 2.0},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 3431,
#   'total': 0.9500000000000001},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 43875,
#   'total': 1.0},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 52171,
#   'total': 0.6000000000000001},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 26820,
#   'total': 1.35},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 60756,
#   'total': 0.8},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 18016,
#   'total': 1.3},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 55306,
#   'total': 2.0},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 35126,
#   'total': 1.5},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 42405,
#   'total': 0.99},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 42885,
#   'total': 1.9},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 32,
#   'total': 1.4},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 24832,
#   'total': 0.9500000000000001},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 28451,
#   'total': 0.55},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 50576,
#   'total': 0.99},
#  {'customer_id': 4054437080,
#   'day': 5,
#   'id': 1392056866,
#   'items': 41218,
#   'total': 1.3},
#  {'customer_id': 3558862810,
#   'day': 5,
#   'id': 2702348912,
#   'items': 27732,
#   'total': 6.5},
#  {'customer_id': 3558862810,
#   'day': 5,
#   'id': 2702348912,
#   'items': 59734,
#   'total': 1.0},
#  {'customer_id': 3558862810,
#   'day': 5,
#   'id': 2702348912,
#   'items': 41231,
#   'total': 3.75},
#  {'customer_id': 3558862810,
#   'day': 5,
#   'id': 2702348912,
#   'items': 31458,
#   'total': 1.5},
#  {'customer_id': 3558862810,
#   'day': 5,
#   'id': 2702348912,
#   'items': 6458,
#   'total': 1.99},
#  {'customer_id': 3558862810,
#   'day': 5,
#   'id': 2702348912,
#   'items': 8557,
#   'total': 2.0},
#  {'customer_id': 3558862810,
#   'day': 5,
#   'id': 2702348912,
#   'items': 41428,
#   'total': 2.2},
#  {'customer_id': 3558862810,
#   'day': 5,
#   'id': 2702348912,
#   'items': 8334,
#   'total': 1.5},
#  {'customer_id': 3558862810,
#   'day': 5,
#   'id': 2702348912,
#   'items': 17910,
#   'total': 1.15},
#  {'customer_id': 3558862810,
#   'day': 5,
#   'id': 2702348912,
#   'items': 52381,
#   'total': 1.25},
#  {'customer_id': 3558862810,
#   'day': 5,
#   'id': 2702348912,
#   'items': 38518,
#   'total': 3.0},
#  {'customer_id': 1720291968,
#   'day': 5,
#   'id': 1208058904,
#   'items': 7737,
#   'total': 1.5},
#  {'customer_id': 1720291968,
#   'day': 5,
#   'id': 1208058904,
#   'items': 61107,
#   'total': 0.5},
#  {'customer_id': 1720291968,
#   'day': 5,
#   'id': 1208058904,
#   'items': 24056,
#   'total': 1.2},
#  {'customer_id': 1720291968,
#   'day': 5,
#   'id': 1208058904,
#   'items': 46980,
#   'total': 1.75},
#  {'customer_id': 1720291968,
#   'day': 5,
#   'id': 1208058904,
#   'items': 35925,
#   'total': 0.89},
#  {'customer_id': 1720291968,
#   'day': 5,
#   'id': 1208058904,
#   'items': 26820,
#   'total': 1.35},
#  {'customer_id': 1720291968,
#   'day': 5,
#   'id': 1208058904,
#   'items': 35731,
#   'total': 6.0},
#  {'customer_id': 1720291968,
#   'day': 5,
#   'id': 1208058904,
#   'items': 27376,
#   'total': 1.79},
#  {'customer_id': 1720291968,
#   'day': 5,
#   'id': 1208058904,
#   'items': 64049,
#   'total': 1.0},
#  {'customer_id': 1720291968,
#   'day': 5,
#   'id': 1208058904,
#   'items': 27787,
#   'total': 1.1},
#  {'customer_id': 1720291968,
#   'day': 5,
#   'id': 1208058904,
#   'items': 39324,
#   'total': 2.85},
#  {'customer_id': 1720291968,
#   'day': 5,
#   'id': 1208058904,
#   'items': 21511,
#   'total': 1.46},
#  {'customer_id': 1720291968,
#   'day': 5,
#   'id': 1208058904,
#   'items': 63594,
#   'total': 1.46},
#  {'customer_id': 1720291968,
#   'day': 5,
#   'id': 1208058904,
#   'items': 49742,
#   'total': 0.9500000000000001},
#  {'customer_id': 1720291968,
#   'day': 5,
#   'id': 1208058904,
#   'items': 65180,
#   'total': 0.35000000000000003},
#  {'customer_id': 3957693635,
#   'day': 5,
#   'id': 370731330,
#   'items': 61457,
#   'total': 21.0},
#  {'customer_id': 3391121701,
#   'day': 5,
#   'id': 241960581,
#   'items': 63381,
#   'total': 0.45},
#  {'customer_id': 3391121701,
#   'day': 5,
#   'id': 241960581,
#   'items': 41765,
#   'total': 1.5},
#  {'customer_id': 3391121701,
#   'day': 5,
#   'id': 241960581,
#   'items': 27893,
#   'total': 0.99},
#  {'customer_id': 3391121701,
#   'day': 5,
#   'id': 241960581,
#   'items': 22633,
#   'total': 1.9},
#  {'customer_id': 3391121701,
#   'day': 5,
#   'id': 241960581,
#   'items': 41069,
#   'total': 3.5},
#  {'customer_id': 3391121701,
#   'day': 5,
#   'id': 241960581,
#   'items': 22633,
#   'total': 1.9},
#  {'customer_id': 3391121701,
#   'day': 5,
#   'id': 241960581,
#   'items': 1614,
#   'total': 3.5},
#  {'customer_id': 3391121701,
#   'day': 5,
#   'id': 241960581,
#   'items': 33533,
#   'total': 0.7000000000000001},
#  {'customer_id': 3391121701,
#   'day': 5,
#   'id': 241960581,
#   'items': 8557,
#   'total': 2.0},
#  {'customer_id': 3391121701,
#   'day': 5,
#   'id': 241960581,
#   'items': 21511,
#   'total': 1.46},
#  {'customer_id': 3391121701,
#   'day': 5,
#   'id': 241960581,
#   'items': 10132,
#   'total': 1.3},
#  {'customer_id': 3391121701,
#   'day': 5,
#   'id': 241960581,
#   'items': 50576,
#   'total': 0.99},
#  {'customer_id': 3391121701,
#   'day': 5,
#   'id': 241960581,
#   'items': 35527,
#   'total': 0.6900000000000001},
#  {'customer_id': 958420868,
#   'day': 6,
#   'id': 1068599081,
#   'items': 31614,
#   'total': 0.88},
#  {'customer_id': 958420868,
#   'day': 6,
#   'id': 1068599081,
#   'items': 55757,
#   'total': 0.9},
#  {'customer_id': 958420868,
#   'day': 6,
#   'id': 1068599081,
#   'items': 3058,
#   'total': 0.9},
#  {'customer_id': 958420868,
#   'day': 6,
#   'id': 1068599081,
#   'items': 50576,
#   'total': 0.99},
#  {'customer_id': 4036240255,
#   'day': 6,
#   'id': 3748169863,
#   'items': 33464,
#   'total': 0.5},
#  {'customer_id': 4036240255,
#   'day': 6,
#   'id': 3748169863,
#   'items': 12388,
#   'total': 2.0},
#  {'customer_id': 4036240255,
#   'day': 6,
#   'id': 3748169863,
#   'items': 20301,
#   'total': 1.3},
#  {'customer_id': 269896857,
#   'day': 6,
#   'id': 2020912488,
#   'items': 7737,
#   'total': 1.5},
#  {'customer_id': 269896857,
#   'day': 6,
#   'id': 2020912488,
#   'items': 52529,
#   'total': 0.9},
#  {'customer_id': 269896857,
#   'day': 6,
#   'id': 2020912488,
#   'items': 5049,
#   'total': 0.5},
#  {'customer_id': 3785220396,
#   'day': 6,
#   'id': 1630625953,
#   'items': 10132,
#   'total': 1.3},
#  {'customer_id': 3785220396,
#   'day': 6,
#   'id': 1630625953,
#   'items': 4284,
#   'total': 2.48},
#  {'customer_id': 3785220396,
#   'day': 6,
#   'id': 1630625953,
#   'items': 14588,
#   'total': 1.15},
#  {'customer_id': 3785220396,
#   'day': 6,
#   'id': 1630625953,
#   'items': 30026,
#   'total': 1.0},
#  {'customer_id': 3785220396,
#   'day': 6,
#   'id': 1630625953,
#   'items': 3628,
#   'total': 0.85},
#  {'customer_id': 3785220396,
#   'day': 6,
#   'id': 1630625953,
#   'items': 52269,
#   'total': 1.0},
#  {'customer_id': 3785220396,
#   'day': 6,
#   'id': 1630625953,
#   'items': 48607,
#   'total': 1.8},
#  {'customer_id': 3785220396,
#   'day': 6,
#   'id': 1630625953,
#   'items': 36381,
#   'total': 1.25},
#  {'customer_id': 3785220396,
#   'day': 6,
#   'id': 1630625953,
#   'items': 43632,
#   'total': 2.5},
#  {'customer_id': 3785220396,
#   'day': 6,
#   'id': 1630625953,
#   'items': 53728,
#   'total': 1.1},
#  {'customer_id': 3785220396,
#   'day': 6,
#   'id': 1630625953,
#   'items': 12132,
#   'total': 9.5},
#  {'customer_id': 3785220396,
#   'day': 6,
#   'id': 1630625953,
#   'items': 18016,
#   'total': 1.3},
#  {'customer_id': 4178248121,
#   'day': 6,
#   'id': 1734212080,
#   'items': 20301,
#   'total': 1.3},
#  {'customer_id': 4178248121,
#   'day': 6,
#   'id': 1734212080,
#   'items': 15694,
#   'total': 5.5},
#  {'customer_id': 4178248121,
#   'day': 6,
#   'id': 1734212080,
#   'items': 47439,
#   'total': 1.5},
#  {'customer_id': 4178248121,
#   'day': 6,
#   'id': 1734212080,
#   'items': 17407,
#   'total': 1.6},
#  {'customer_id': 4178248121,
#   'day': 6,
#   'id': 1734212080,
#   'items': 3776,
#   'total': 1.65},
#  {'customer_id': 4178248121,
#   'day': 6,
#   'id': 1734212080,
#   'items': 52381,
#   'total': 1.25},
#  {'customer_id': 4178248121,
#   'day': 6,
#   'id': 1734212080,
#   'items': 25070,
#   'total': 1.3},
#  {'customer_id': 4178248121,
#   'day': 6,
#   'id': 1734212080,
#   'items': 33067,
#   'total': 0.9},
#  {'customer_id': 4178248121,
#   'day': 6,
#   'id': 1734212080,
#   'items': 63618,
#   'total': 4.0},
#  {'customer_id': 4178248121,
#   'day': 6,
#   'id': 1734212080,
#   'items': 15694,
#   'total': 5.5},
#  {'customer_id': 4178248121,
#   'day': 6,
#   'id': 1734212080,
#   'items': 30113,
#   'total': 1.9500000000000002},
#  {'customer_id': 3505877984,
#   'day': 6,
#   'id': 1719069667,
#   'items': 12612,
#   'total': 1.1},
#  {'customer_id': 3505877984,
#   'day': 6,
#   'id': 1719069667,
#   'items': 25512,
#   'total': 1.0},
#  {'customer_id': 3505877984,
#   'day': 6,
#   'id': 1719069667,
#   'items': 8560,
#   'total': 3.0},
#  {'customer_id': 3505877984,
#   'day': 6,
#   'id': 1719069667,
#   'items': 27610,
#   'total': 2.95},
#  {'customer_id': 3505877984,
#   'day': 6,
#   'id': 1719069667,
#   'items': 60918,
#   'total': 1.0},
#  {'customer_id': 3505877984,
#   'day': 6,
#   'id': 1719069667,
#   'items': 18016,
#   'total': 1.3},
#  {'customer_id': 3505877984,
#   'day': 6,
#   'id': 1719069667,
#   'items': 31614,
#   'total': 0.88},
#  {'customer_id': 3505877984,
#   'day': 6,
#   'id': 1719069667,
#   'items': 35925,
#   'total': 0.89},
#  {'customer_id': 3505877984,
#   'day': 6,
#   'id': 1719069667,
#   'items': 60151,
#   'total': 9.75},
#  {'customer_id': 3505877984,
#   'day': 6,
#   'id': 1719069667,
#   'items': 53480,
#   'total': 0.75},
#  {'customer_id': 3505877984,
#   'day': 6,
#   'id': 1719069667,
#   'items': 62913,
#   'total': 1.8},
#  {'customer_id': 3505877984,
#   'day': 6,
#   'id': 1719069667,
#   'items': 11726,
#   'total': 0.85},
#  {'customer_id': 1232284025,
#   'day': 6,
#   'id': 2693356827,
#   'items': 49315,
#   'total': 7.5},
#  {'customer_id': 1232284025,
#   'day': 6,
#   'id': 2693356827,
#   'items': 7969,
#   'total': 2.35},
#  {'customer_id': 1232284025,
#   'day': 6,
#   'id': 2693356827,
#   'items': 24737,
#   'total': 2.9},
#  {'customer_id': 1232284025,
#   'day': 6,
#   'id': 2693356827,
#   'items': 27610,
#   'total': 2.95},
#  {'customer_id': 1232284025,
#   'day': 6,
#   'id': 2693356827,
#   'items': 2648,
#   'total': 2.0},
#  {'customer_id': 1232284025,
#   'day': 6,
#   'id': 2693356827,
#   'items': 21511,
#   'total': 1.46},
#  {'customer_id': 1232284025,
#   'day': 6,
#   'id': 2693356827,
#   'items': 4284,
#   'total': 2.48},
#  {'customer_id': 1232284025,
#   'day': 6,
#   'id': 2693356827,
#   'items': 3628,
#   'total': 0.85},
#  {'customer_id': 1232284025,
#   'day': 6,
#   'id': 2693356827,
#   'items': 38837,
#   'total': 3.5},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 6133,
#   'total': 1.77},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 48607,
#   'total': 1.8},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 25592,
#   'total': 1.0},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 35527,
#   'total': 0.6900000000000001},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 8334,
#   'total': 1.5},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 25070,
#   'total': 1.3},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 8334,
#   'total': 1.5},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 8560,
#   'total': 3.0},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 1960,
#   'total': 1.79},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 25652,
#   'total': 1.46},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 41069,
#   'total': 3.5},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 17440,
#   'total': 1.25},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 37577,
#   'total': 0.85},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 26335,
#   'total': 0.7000000000000001},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 46361,
#   'total': 1.15},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 25592,
#   'total': 1.0},
#  {'customer_id': 824870520,
#   'day': 6,
#   'id': 70746943,
#   'items': 22633,
#   'total': 1.9},
#  {'customer_id': 3396477435,
#   'day': 6,
#   'id': 1471344127,
#   'items': 32,
#   'total': 1.4},
#  {'customer_id': 3396477435,
#   'day': 6,
#   'id': 1471344127,
#   'items': 53453,
#   'total': 1.55},
#  {'customer_id': 3396477435,
#   'day': 6,
#   'id': 1471344127,
#   'items': 27893,
#   'total': 0.99},
#  {'customer_id': 3396477435,
#   'day': 6,
#   'id': 1471344127,
#   'items': 17910,
#   'total': 1.15},
#  {'customer_id': 3396477435,
#   'day': 6,
#   'id': 1471344127,
#   'items': 64051,
#   'total': 1.2},
#  {'customer_id': 3396477435,
#   'day': 6,
#   'id': 1471344127,
#   'items': 6133,
#   'total': 1.77},
#  {'customer_id': 3396477435,
#   'day': 6,
#   'id': 1471344127,
#   'items': 35566,
#   'total': 1.0},
#  {'customer_id': 3396477435,
#   'day': 6,
#   'id': 1471344127,
#   'items': 2846,
#   'total': 2.95},
#  {'customer_id': 3396477435,
#   'day': 6,
#   'id': 1471344127,
#   'items': 10921,
#   'total': 1.5},
#  {'customer_id': 3396477435,
#   'day': 6,
#   'id': 1471344127,
#   'items': 24958,
#   'total': 3.0},
#  {'customer_id': 3396477435,
#   'day': 6,
#   'id': 1471344127,
#   'items': 27732,
#   'total': 6.5},
#  {'customer_id': 1504822002,
#   'day': 6,
#   'id': 1934826705,
#   'items': 24958,
#   'total': 3.0},
#  {'customer_id': 1504822002,
#   'day': 6,
#   'id': 1934826705,
#   'items': 12543,
#   'total': 1.0},
#  {'customer_id': 1504822002,
#   'day': 6,
#   'id': 1934826705,
#   'items': 63381,
#   'total': 0.45},
#  {'customer_id': 1504822002,
#   'day': 6,
#   'id': 1934826705,
#   'items': 41371,
#   'total': 0.6000000000000001},
#  {'customer_id': 1504822002,
#   'day': 6,
#   'id': 1934826705,
#   'items': 34797,
#   'total': 2.5},
#  {'customer_id': 1504822002,
#   'day': 6,
#   'id': 1934826705,
#   'items': 31803,
#   'total': 10.49},
#  {'customer_id': 1504822002,
#   'day': 6,
#   'id': 1934826705,
#   'items': 43094,
#   'total': 1.5},
#  {'customer_id': 1504822002,
#   'day': 6,
#   'id': 1934826705,
#   'items': 41428,
#   'total': 2.2},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 1750,
#   'total': 4.0},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 31297,
#   'total': 1.1},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 61107,
#   'total': 0.5},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 50576,
#   'total': 0.99},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 42405,
#   'total': 0.99},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 43875,
#   'total': 1.0},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 41069,
#   'total': 3.5},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 26820,
#   'total': 1.35},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 51974,
#   'total': 0.99},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 52269,
#   'total': 1.0},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 53646,
#   'total': 1.35},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 53646,
#   'total': 1.35},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 11836,
#   'total': 2.0},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 16846,
#   'total': 1.0},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 46980,
#   'total': 1.75},
#  {'customer_id': 1660986885,
#   'day': 6,
#   'id': 2914557183,
#   'items': 27610,
#   'total': 2.95}]

# %% [markdown]
# We want to store the data in an as granular a format as possible, as it will make it easier to both store in a SQL database, or process in pandas DataFrames (or other DataFrame libraries, like data.table, dask, and so on).
#
# The final step is to create a timestamp for each transaction! We have a day, all we need now is to generate hour/minutes/seconds for each transaction. We will do this by using python's builtin `random` module. We will assume our store opens at 8am and closes at 10pm.

# %%
import random

def generate_time() -> tuple:
    """Generates a random time between 8am and 10pm, when our store is open."""
    rtime   = int(random.random() * 86_400)
    
    hours   = rtime//3600
    minutes = (rtime - hours*3600)//60
    seconds = rtime - hours*3600 - minutes*60

    if (hours <= 8) or (hours >= 22):
        return generate_time()
    else:
        return hours, minutes, seconds

# %% [markdown]
# For looping through datetimes, we can rely on pandas' function, `pd.date_range`, in which we can define a starting date, ending date, and frequency. We can then use `datetime.timedelta` to generate the final datetime, and then get the timestamp.

# %%
from datetime import timedelta

# %%
def generate_timestamp(date):
    """Returns a UNIX timestamp for a given date + random time."""
    return int((date + timedelta(*generate_time())).timestamp())

# %%
generate_timestamp(pd.date_range(start='2031-01-01', end='2031-01-08')[0])
# Out:
# 1926547240

# %% [markdown]
# ### Putting it all together
#
# Now that we have everything in place, let's generate a sample of the data we are looking to simulate. Let's generate 1 week's worth of transactions!

# %%
billings = []
for day in pd.date_range(start='2031-01-01', end='2031-01-08'):
    # we get the weekday from the timestamp
    todays_customers = customers.query('habit == "daily"').append(
        weekly_customers.query(f'day_in == {int(day.strftime("%w"))}')
    )
    for idx,customer in todays_customers.set_index('uuid').iterrows():
        bill = generate_bill(customer, items)
        bill_id = uuid.uuid4().fields[0]
        for it,pr in zip(bill[0], bill[1]):
            billings.append(
                {
                    'id': bill_id,
                    'timestamp': generate_timestamp(day),
                    'customer_id': idx,
                    'items': it,
                    'total': pr
                }
            )
pprint(billings[:10])
# Out:
# [{'customer_id': 958420868,
#   'id': 3526142073,
#   'items': 23339,
#   'timestamp': 1926028826,
#   'total': 1.0},
#  {'customer_id': 958420868,
#   'id': 3526142073,
#   'items': 43692,
#   'timestamp': 1926806415,
#   'total': 1.5},
#  {'customer_id': 4036240255,
#   'id': 2343320927,
#   'items': 53646,
#   'timestamp': 1926547255,
#   'total': 1.35},
#  {'customer_id': 269896857,
#   'id': 651960562,
#   'items': 53480,
#   'timestamp': 1926028855,
#   'total': 0.75},
#  {'customer_id': 269896857,
#   'id': 651960562,
#   'items': 35527,
#   'timestamp': 1926720037,
#   'total': 0.6900000000000001},
#  {'customer_id': 961301073,
#   'id': 3461929721,
#   'items': 3410,
#   'timestamp': 1926115212,
#   'total': 1.0},
#  {'customer_id': 961301073,
#   'id': 3461929721,
#   'items': 32,
#   'timestamp': 1926201622,
#   'total': 1.4},
#  {'customer_id': 961301073,
#   'id': 3461929721,
#   'items': 35126,
#   'timestamp': 1926806425,
#   'total': 1.5},
#  {'customer_id': 961301073,
#   'id': 3461929721,
#   'items': 28174,
#   'timestamp': 1926201610,
#   'total': 2.0},
#  {'customer_id': 961301073,
#   'id': 3461929721,
#   'items': 18633,
#   'timestamp': 1926547228,
#   'total': 0.7000000000000001}]

# %% [markdown]
# Awesome! We can analyse the results better by converting them to a DataFrame.

# %%
pd.DataFrame(billings).head(10)
# Out:
#            id   timestamp  customer_id  items  total
# 0  3526142073  1926028826    958420868  23339   1.00
# 1  3526142073  1926806415    958420868  43692   1.50
# 2  2343320927  1926547255   4036240255  53646   1.35
# 3   651960562  1926028855    269896857  53480   0.75
# 4   651960562  1926720037    269896857  35527   0.69
# 5  3461929721  1926115212    961301073   3410   1.00
# 6  3461929721  1926201622    961301073     32   1.40
# 7  3461929721  1926806425    961301073  35126   1.50
# 8  3461929721  1926201610    961301073  28174   2.00
# 9  3461929721  1926547228    961301073  18633   0.70

# %% [markdown]
# With this, we now have a repeatable way of generating billings for any number of days.
#
# In the next notebook, we will generate billings for 1 year, which will include the sporadic customers.

# %%
day.day
# Out:
# 8
